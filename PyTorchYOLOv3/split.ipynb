# %%
# !ls
# Out:
# command.txt  detect.py	output	     README.md	       test_image  utils
# config	     LICENSE	patch_file   requirements.txt  test.py	   weights
# data	     models.py	__pycache__  split.ipynb       train.py

# %%
# !ls
import os
import shutil 
train_path = 'data/custom/labels/train/'
val_path = 'data/custom/labels/val/'

f=open('data/custom/valid.txt','r+')

def read_path(file_path):
    #遍历该目录下的所有图片文件
    for filename in os.listdir(file_path):
        out_path='data/custom/images/val/'+filename[:-4]+'.jpg'
        print(out_path)
        f.write(out_path+'\n')


                    
                

read_path(val_path)
# Out:
# command.txt  detect.py	output	     README.md	       test_image  utils
# config	     LICENSE	patch_file   requirements.txt  test.py	   weights
# data	     models.py	__pycache__  split.ipynb       train.py
# data/custom/images/val/55320.jpg
# data/custom/images/val/57976.jpg
# data/custom/images/val/23762.jpg
# data/custom/images/val/58660.jpg
# data/custom/images/val/89987.jpg
# data/custom/images/val/94665.jpg
# data/custom/images/val/53027.jpg
# data/custom/images/val/86090.jpg
# data/custom/images/val/21584.jpg
# data/custom/images/val/92152.jpg
# data/custom/images/val/58816.jpg
# data/custom/images/val/28456.jpg
# data/custom/images/val/25027.jpg
# data/custom/images/val/40491.jpg
# data/custom/images/val/69524.jpg
# data/custom/images/val/29976.jpg
# data/custom/images/val/59511.jpg
# data/custom/images/val/41963.jpg
# data/custom/images/val/62167.jpg
# data/custom/images/val/26615.jpg
# data/custom/images/val/61276.jpg
# data/custom/images/val/55983.jpg
# ...
